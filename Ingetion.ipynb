# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("creating_table").getOrCreate()

spark.sql("""

create table group_main_prod.bronze.cust_fact(

cust_id int,
cust_name varchar(20),
city varchar(20),
contact_no varchar(20)

)

""");

# %%
# %sql
select * from group_main_prod.bronze.cust_fact;
